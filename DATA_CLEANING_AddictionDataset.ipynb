# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('Time-Wasters on Social Media.csv')

# %%
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  Total Time Spent  \
# 0       Engineer        Rural  Instagram                80
# 1         Artist        Urban  Instagram               228
# 2       Engineer        Rural   Facebook                30
# 3  Waiting staff        Rural    YouTube               101
# 4        Manager        Urban     TikTok               136
#
#    Number of Sessions  Video ID Video Category  Video Length  Engagement  \
# 0                  17      4229         Pranks            24        7867
# ...

# %%
df.shape
# Out:
# (1000, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
df.describe()
# Out:
#             UserID          Age        Income  Total Time Spent  \
# count  1000.000000  1000.000000   1000.000000       1000.000000
# mean    500.500000    40.986000  59524.213000        151.406000
# std     288.819436    13.497852  23736.212925         83.952637
# min       1.000000    18.000000  20138.000000         10.000000
# 25%     250.750000    29.000000  38675.250000         78.000000
# 50%     500.500000    42.000000  58805.000000        152.000000
# 75%     750.250000    52.000000  79792.250000        223.000000
# max    1000.000000    64.000000  99676.000000        298.000000
#
#        Number of Sessions     Video ID  Video Length   Engagement  \
# count         1000.000000  1000.000000   1000.000000  1000.000000
# mean            10.013000  4891.738000     15.214000  4997.159000
# std              5.380314  2853.144258      8.224953  2910.053701
# min              1.000000    11.000000      1.000000    15.000000
# ...

# %%
temp_df = df.select_dtypes(exclude=['object','bool'])

# %%
temp_df.shape
# Out:
# (1000, 16)

# %%
temp_df.corr()
# Out:
#                             UserID       Age    Income  Total Time Spent  \
# UserID                    1.000000 -0.024857  0.056221          0.035689
# Age                      -0.024857  1.000000 -0.017923         -0.004166
# Income                    0.056221 -0.017923  1.000000          0.013326
# Total Time Spent          0.035689 -0.004166  0.013326          1.000000
# Number of Sessions        0.022750  0.006563 -0.009979         -0.013876
# Video ID                  0.002670  0.047762  0.003320         -0.018057
# Video Length             -0.037910  0.009557  0.017432          0.068607
# Engagement               -0.013374  0.010417 -0.017183         -0.033743
# Importance Score          0.009265 -0.014994 -0.000762         -0.043414
# Time Spent On Video      -0.055781  0.034535 -0.041666          0.053319
# Number of Videos Watched  0.002627 -0.033776 -0.036211         -0.020969
# Scroll Rate               0.025134 -0.018768  0.029066          0.004211
# ...

# %%
sns.heatmap(temp_df.corr())
# Out:
# <Axes: >

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      514
# Female    322
# Other     164
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.heatmap(pd.crosstab(df['Gender'],df['Addiction Level']))
# Out:
# <Axes: xlabel='Addiction Level', ylabel='Gender'>

# %%
df.groupby('Addiction Level')['Gender'].value_counts()
# Out:
# Addiction Level  Gender
# 0                Male       89
#                  Female     61
#                  Other      30
# 1                Male       31
#                  Female     21
#                  Other       8
# 2                Male      122
#                  Female     79
#                  Other      47
# 3                Male       81
#                  Female     45
#                  Other      33
# 4                Male       25
#                  Female      7
#                  Other       4
# 5                Male      118
#                  Female     80
#                  Other      30
# 6                Male       20
#                  Female      9
#                  Other       5
# 7                Male       28
#                  Female     20
#                  Other       7
# Name: count, dtype: int64

# %%
(pd.crosstab(df['Gender'],df['Addiction Level'],normalize='columns')*100)
# Out:
# Addiction Level          0          1          2          3          4  \
# Gender
# Female           33.888889  35.000000  31.854839  28.301887  19.444444
# Male             49.444444  51.666667  49.193548  50.943396  69.444444
# Other            16.666667  13.333333  18.951613  20.754717  11.111111
#
# Addiction Level          5          6          7
# Gender
# Female           35.087719  26.470588  36.363636
# Male             51.754386  58.823529  50.909091
# Other            13.157895  14.705882  12.727273

# %%
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  Total Time Spent  \
# 0       Engineer        Rural  Instagram                80
# 1         Artist        Urban  Instagram               228
# 2       Engineer        Rural   Facebook                30
# 3  Waiting staff        Rural    YouTube               101
# 4        Manager        Urban     TikTok               136
#
#    Number of Sessions  Video ID Video Category  Video Length  Engagement  \
# 0                  17      4229         Pranks            24        7867
# ...

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
sns.displot(kind='hist',data=df,x='Age',kde=True,bins=20)
# Out:
# C:\Users\TIRTH PATEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=df,y='Addiction Level',x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Addiction Level'>

# %%
df['Location'].value_counts()
# Out:
# Location
# India            228
# United States    174
# Vietnam           82
# Barzil            78
# Philippines       78
# Indonesia         77
# Pakistan          76
# Japan             75
# Mexico            73
# Germany           59
# Name: count, dtype: int64

# %%
df['Location'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.groupby('Addiction Level')['Location'].value_counts()
# Out:
# Addiction Level  Location
# 0                India            34
#                  United States    29
#                  Vietnam          22
#                  Pakistan         19
#                  Indonesia        17
#                  Mexico           15
#                  Japan            14
#                  Philippines      12
#                  Germany          12
#                  Barzil            6
# 1                India            17
#                  United States    12
#                  Japan             9
#                  Vietnam           4
#                  Mexico            4
#                  Barzil            3
#                  Indonesia         3
#                  Pakistan          3
#                  Philippines       3
#                  Germany           2
# 2                India            60
#                  United States    43
#                  Japan            24
#                  Philippines      24
# ...

# %%
(pd.crosstab(df['Location'],df['Addiction Level'],normalize='columns')*100)
# Out:
# Addiction Level          0          1          2          3          4  \
# Location
# Barzil            3.333333   5.000000   6.451613  10.691824   5.555556
# Germany           6.666667   3.333333   3.225806   8.176101   5.555556
# India            18.888889  28.333333  24.193548  23.270440  27.777778
# Indonesia         9.444444   5.000000   8.870968   5.031447   5.555556
# Japan             7.777778  15.000000   9.677419   4.402516   0.000000
# Mexico            8.333333   6.666667   6.854839   6.289308   8.333333
# Pakistan         10.555556   5.000000   7.258065   6.918239  13.888889
# Philippines       6.666667   5.000000   9.677419   9.433962   2.777778
# United States    16.111111  20.000000  17.338710  16.981132  22.222222
# Vietnam          12.222222   6.666667   6.451613   8.805031   8.333333
#
# Addiction Level          5          6          7
# Location
# Barzil           12.719298   8.823529   3.636364
# Germany           6.578947  11.764706   5.454545
# ...

# %%
sns.barplot(data=df,y='Location',x='Addiction Level')
# Out:
# <Axes: xlabel='Addiction Level', ylabel='Location'>

# %%
df['Debt'].value_counts()
# Out:
# Debt
# True     599
# False    401
# Name: count, dtype: int64

# %%
df.groupby('Addiction Level')['Debt'].value_counts()
# Out:
# Addiction Level  Debt
# 0                True     116
#                  False     64
# 1                True      42
#                  False     18
# 2                True     144
#                  False    104
# 3                True      96
#                  False     63
# 4                False     18
#                  True      18
# 5                True     130
#                  False     98
# 6                True      23
#                  False     11
# 7                True      30
#                  False     25
# Name: count, dtype: int64

# %%
(pd.crosstab(df['Debt'],df['Addiction Level'],normalize='columns')*100)
# Out:
# Addiction Level          0     1          2          3     4          5  \
# Debt
# False            35.555556  30.0  41.935484  39.622642  50.0  42.982456
# True             64.444444  70.0  58.064516  60.377358  50.0  57.017544
#
# Addiction Level          6          7
# Debt
# False            32.352941  45.454545
# True             67.647059  54.545455

# %%
sns.barplot(data=df,x='Debt',y='Addiction Level')
# Out:
# <Axes: xlabel='Debt', ylabel='Addiction Level'>

# %%
sns.heatmap(pd.crosstab(df['Debt'],df['Addiction Level']))
# Out:
# <Axes: xlabel='Addiction Level', ylabel='Debt'>

# %%
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  Total Time Spent  \
# 0       Engineer        Rural  Instagram                80
# 1         Artist        Urban  Instagram               228
# 2       Engineer        Rural   Facebook                30
# 3  Waiting staff        Rural    YouTube               101
# 4        Manager        Urban     TikTok               136
#
#    Number of Sessions  Video ID Video Category  Video Length  Engagement  \
# 0                  17      4229         Pranks            24        7867
# ...

# %%
df['Owns Property'].value_counts()
# Out:
# Owns Property
# True     542
# False    458
# Name: count, dtype: int64

# %%
df.groupby('Addiction Level')['Owns Property'].value_counts()
# Out:
# Addiction Level  Owns Property
# 0                True             115
#                  False             65
# 1                False             31
#                  True              29
# 2                False            128
#                  True             120
# 3                True              96
#                  False             63
# 4                True              19
#                  False             17
# 5                False            116
#                  True             112
# 6                True              20
#                  False             14
# 7                True              31
#                  False             24
# Name: count, dtype: int64

# %%
df['Profession'].value_counts()
# Out:
# Profession
# Students         246
# Waiting staff    194
# Labor/Worker     186
# driver           113
# Engineer          65
# Cashier           56
# Manager           54
# Artist            47
# Teacher           39
# Name: count, dtype: int64

# %%
df['Profession'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(data=df,y='Profession',x='Addiction Level')
# Out:
# <Axes: xlabel='Addiction Level', ylabel='Profession'>

# %%
sns.heatmap(pd.crosstab(df['Profession'],df['Addiction Level']))
# Out:
# <Axes: xlabel='Addiction Level', ylabel='Profession'>

# %%
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  Total Time Spent  \
# 0       Engineer        Rural  Instagram                80
# 1         Artist        Urban  Instagram               228
# 2       Engineer        Rural   Facebook                30
# 3  Waiting staff        Rural    YouTube               101
# 4        Manager        Urban     TikTok               136
#
#    Number of Sessions  Video ID Video Category  Video Length  Engagement  \
# 0                  17      4229         Pranks            24        7867
# ...

# %%
x = temp_df.drop(columns=['Satisfaction'])

# %%
df['Addiction Level'] = x['Addiction Level'].replace({0: 'low', 1: 'low',
                                                     2: 'moderate', 3: 'moderate', 4: 'moderate',
                                                     5: 'high', 6: 'high', 7: 'extreme'})

# %%
x['Addiction Level'] = x['Addiction Level'].replace({ 'low':0,  'low':1,
                                                      'moderate':2,  'moderate':3,  'moderate':4,
                                                      'high':5,  'high':6,  'high':7})

# %%
x.corr()['Addiction Level'].sort_values(ascending=False)
# Out:
# Addiction Level             1.000000
# Age                         0.033493
# Engagement                  0.027620
# Video ID                    0.020655
# Importance Score            0.018474
# Total Time Spent            0.016086
# Number of Videos Watched    0.013286
# Scroll Rate                 0.006758
# Video Length                0.004914
# Time Spent On Video        -0.000447
# Income                     -0.039181
# Number of Sessions         -0.080961
# UserID                     -0.105280
# ProductivityLoss           -0.994939
# Self Control               -1.000000
# Name: Addiction Level, dtype: float64

# %%
df['Addiction Level'].value_counts()
# Out:
# Addiction Level
# moderate    443
# high        317
# low         240
# Name: count, dtype: int64

# %%
df
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# 5         6   38    Male        Vietnam   45279  False          False
# 6         7   56    Male          India   46201  False          False
# 7         8   36    Male         Barzil   39715  False          False
# 8         9   40    Male  United States   49309  False          False
# 9        10   28   Other  United States   35078  False          False
# 10       11   28    Male      Indonesia   76614   True           True
# 11       12   41   Other    Philippines   25105  False          False
# ...

# %%
Temp_df = df.copy()

# %%
x['Owns Property'] = Temp_df['Owns Property'].replace({'False': 0, 'True': 1})

# %%
x['Gender'] = Temp_df['Gender']

# %%
x.corr()['Addiction Level'].sort_values(ascending=False)
# Out:
# Addiction Level             1.000000
# Frequency                   0.183081
# Gender                      0.027201
# Engagement                  0.021253
# Age                         0.020976
# Total Time Spent            0.018875
# Importance Score            0.018299
# Video Length                0.016800
# Scroll Rate                 0.009297
# Time Spent On Video         0.008888
# Video ID                    0.008590
# Number of Videos Watched   -0.001642
# Platform                   -0.004536
# Demographics               -0.004821
# Income                     -0.049396
# Debt                       -0.058059
# Owns Property              -0.061467
# Number of Sessions         -0.072394
# UserID                     -0.175041
# ProductivityLoss           -0.943362
# Self Control               -0.946244
# Name: Addiction Level, dtype: float64

# %%
df
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# 5         6   38    Male        Vietnam   45279  False          False
# 6         7   56    Male          India   46201  False          False
# 7         8   36    Male         Barzil   39715  False          False
# 8         9   40    Male  United States   49309  False          False
# 9        10   28   Other  United States   35078  False          False
# 10       11   28    Male      Indonesia   76614   True           True
# 11       12   41   Other    Philippines   25105  False          False
# ...

# %% [markdown]
# remove : Demographics,Platform,CurrentActivity,ConnectionType,Video ID,User ID,Importance Score,Scroll Rate

# %%
df['OS'].value_counts()
# Out:
# OS
# Android    500
# iOS        261
# Windows    123
# MacOS      116
# Name: count, dtype: int64

# %%
Temp_df['Addiction Level'] = Temp_df['Addiction Level'].replace({ 'low':0,  'low':1,
                                                      'moderate':2,  'moderate':3,  'moderate':4,
                                                      'high':5,  'high':6,  'high':7})

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=Temp_df,x='Satisfaction',y='Addiction Level')
# Out:
# <Axes: xlabel='Satisfaction', ylabel='Addiction Level'>

# %%
sns.scatterplot(data=Temp_df,y = 'Income',x = 'Addiction Level')
# Out:
# <Axes: xlabel='Addiction Level', ylabel='Income'>

# %%
sns.displot(kind='hist',data=df,x='Income',kde=True,bins=20)
# Out:
# C:\Users\TIRTH PATEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df['Income'])
# Out:
# <Axes: >

# %%
sns.displot(kind='hist',data=df,x='Addiction Level')
# Out:
# C:\Users\TIRTH PATEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Addiction Level'].value_counts()
# Out:
# Addiction Level
# moderate    443
# extreme     317
# low         240
# Name: count, dtype: int64
